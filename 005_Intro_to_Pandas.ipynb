# %% [markdown]
# # Intro Pandas
# ### Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# ### First we look at Series

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
# a Series is like an array, but it's indexed
obj = Series([1,2,3,4,5])
obj
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# print just the values and indexes
print(obj.values)
print(obj.index)
# Out:
# [1 2 3 4 5]
# RangeIndex(start=0, stop=5, step=1)

# %%
# create a Series for WW2 casualties
ww2_cas = Series([87000000, 43000000, 3000000, 2100000, 400000], index = ['USSR','Germany', 'China', 'Japan', 'USA'])
ww2_cas
# Out:
# USSR       87000000
# Germany    43000000
# China       3000000
# Japan       2100000
# USA          400000
# dtype: int64

# %%
ww2_cas['Germany']
# Out:
# 43000000

# %%
# Check wich coutries had casualties greater than 4 mill
ww2_cas[ww2_cas > 4000000]
# Out:
# USSR       87000000
# Germany    43000000
# dtype: int64

# %%
# We can tread the Series as an ordered dictionary
'USSR' in ww2_cas
# Out:
# True

# %%
# we can create a dictionary from this
ww2_dict = ww2_cas.to_dict()
ww2_dict
# Out:
# {'USSR': 87000000,
#  'Germany': 43000000,
#  'China': 3000000,
#  'Japan': 2100000,
#  'USA': 400000}

# %%
# we can feed dictionaries into series
ww2_series = Series(ww2_dict)
ww2_series
# Out:
# USSR       87000000
# Germany    43000000
# China       3000000
# Japan       2100000
# USA          400000
# dtype: int64

# %%
# index a Series with a list, Argentina is not in the Series so it will give it NaN as a value
countries = ['China', 'Germany', 'Japan', 'Argentina']
obj2 = Series(ww2_dict, index = countries)
obj2
# Out:
# China         3000000.0
# Germany      43000000.0
# Japan         2100000.0
# Argentina           NaN
# dtype: float64

# %%
# isnull -> True if null, notnull -> True if notnull
pd.isnull(obj2)
# Out:
# China        False
# Germany      False
# Japan        False
# Argentina     True
# dtype: bool

# %%
pd.notnull(obj2)
# Out:
# China         True
# Germany       True
# Japan         True
# Argentina    False
# dtype: bool

# %%
ww2_series
# Out:
# USSR       87000000
# Germany    43000000
# China       3000000
# Japan       2100000
# USA          400000
# dtype: int64

# %%
# add together two series
ww2_series + obj2
# Out:
# Argentina           NaN
# China         6000000.0
# Germany      86000000.0
# Japan         4200000.0
# USA                 NaN
# USSR                NaN
# dtype: float64

# %%
# name the series
obj2.name = "World War 2 Casualties"
obj2
# Out:
# China         3000000.0
# Germany      43000000.0
# Japan         2100000.0
# Argentina           NaN
# Name: World War 2 Casualties, dtype: float64

# %%
# name the index
obj2.index.name = "Coutries"
obj2
# Out:
# Coutries
# China         3000000.0
# Germany      43000000.0
# Japan         2100000.0
# Argentina           NaN
# Name: World War 2 Casualties, dtype: float64

# %% [markdown]
# ## Intro to DataFrames

# %%
import webbrowser
website = 'https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'

webbrowser.open(website)
# copy table to clipboard
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()
nfl_frame
# Out:
#    Rank                   Team      GP   Won   Lost   Tied   Pct.   \
# 0      1        Dallas Cowboys     914    520    388      6  0.572
# 1      2     Green Bay Packers   1,368    756    574     38  0.567
# 2      3  New England Patriots     916    512    395      9  0.564
# 3      4         Chicago Bears   1,402    769    591     42  0.563
# 4      5      Baltimore Ravens     384    214    169      1  0.559
# 5      6        Miami Dolphins     832    457    371      4  0.552
# 6      7     Minnesota Vikings     902    488    403     11  0.547
# 7      8   San Francisco 49ers   1,034    545    475     14  0.534
# 8      9       New York Giants   1,337    696    608     33  0.533
# 9     10        Denver Broncos     916    483    423     10  0.533
#
#    First NFL Season    Division
# 0               1960   NFC East
# 1               1921  NFC North
# 2               1960   AFC East
# 3               1920  NFC North
# 4               1996  AFC North
# 5               1966   AFC East
# 6               1961  NFC North
# 7               1950   NFC West
# 8               1925   NFC East
# 9               1960   AFC West

# %%
# read all data from CSV
nfl_data = pd.read_csv('nfl_data.csv', sep=';') 
nfl_data
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# 14    15      Seattle Seahawks    692  355   336     1  0.514
# 15    16      Los Angeles Rams  1,167  577   569    21  0.503
# 16    17   Washington Redskins  1,234  603   603    28  0.500
# 17    18  Los Angeles Chargers    916  452   453    11  0.499
# 18    19   Philadelphia Eagles   1,22  586   608    26  0.491
# 19    20     Carolina Panthers    400  195   204     1  0.489
# 20    21      Cleveland Browns    986  475   500    11  0.487
# 21    22      Tennessee Titans    916  440   470     6  0.484
# 22    23         Buffalo Bills    916  425   483     8  0.468
# 23    24    New Orleans Saints    818  375   438     5  0.461
# 24    25         Detroit Lions  1,265  562   670    33  0.457
# 25    26        Houston Texans    288  131   157     0  0.455
# 26    27         New York Jets    916  408   500     8  0.450
# 27    28    Cincinnati Bengals    804  359   441     4  0.449
# 28    29       Atlanta Falcons    832  365   461     6  0.448
# 29    30  Jacksonville Jaguars    400  176   224     0  0.440
# 30    31     Arizona Cardinals  1,362  558   763    41  0.425
# 31    32  Tampa Bay Buccaneers    692  267   424     1  0.387
#
#     First NFL Season   Division
# 0               1960   NFC East
# 1               1921  NFC North
# 2               1960   AFC East
# 3               1920  NFC North
# 4               1996  AFC North
# 5               1966   AFC East
# 6               1961  NFC North
# 7               1950   NFC West
# 8               1925   NFC East
# 9               1960   AFC West
# 10              1960   AFC West
# 11              1933  AFC North
# 12              1953  AFC South
# 13              1960   AFC West
# 14              1976   NFC West
# 15              1937   NFC West
# 16              1932   NFC East
# 17              1960   AFC West
# 18              1933   NFC East
# 19              1995  NFC South
# 20              1950  AFC North
# 21              1960  AFC South
# 22              1960   AFC East
# 23              1967  NFC South
# 24              1930  NFC North
# 25              2002  AFC South
# 26              1960   AFC East
# 27              1968  AFC North
# 28              1966  NFC South
# 29              1995  AFC South
# 30              1920   NFC West
# 31              1976  NFC South

# %%
nfl_data2 = DataFrame(nfl_data, columns = ['Team', 'First NFL Season', 'Division'])
nfl_data2
# Out:
#                     Team  First NFL Season   Division
# 0         Dallas Cowboys              1960   NFC East
# 1      Green Bay Packers              1921  NFC North
# 2   New England Patriots              1960   AFC East
# 3          Chicago Bears              1920  NFC North
# 4       Baltimore Ravens              1996  AFC North
# 5         Miami Dolphins              1966   AFC East
# 6      Minnesota Vikings              1961  NFC North
# 7    San Francisco 49ers              1950   NFC West
# 8        New York Giants              1925   NFC East
# 9         Denver Broncos              1960   AFC West
# 10    Kansas City Chiefs              1960   AFC West
# 11   Pittsburgh Steelers              1933  AFC North
# 12    Indianapolis Colts              1953  AFC South
# 13     Las Vegas Raiders              1960   AFC West
# 14      Seattle Seahawks              1976   NFC West
# 15      Los Angeles Rams              1937   NFC West
# 16   Washington Redskins              1932   NFC East
# 17  Los Angeles Chargers              1960   AFC West
# 18   Philadelphia Eagles              1933   NFC East
# 19     Carolina Panthers              1995  NFC South
# 20      Cleveland Browns              1950  AFC North
# 21      Tennessee Titans              1960  AFC South
# 22         Buffalo Bills              1960   AFC East
# 23    New Orleans Saints              1967  NFC South
# 24         Detroit Lions              1930  NFC North
# 25        Houston Texans              2002  AFC South
# 26         New York Jets              1960   AFC East
# 27    Cincinnati Bengals              1968  AFC North
# 28       Atlanta Falcons              1966  NFC South
# 29  Jacksonville Jaguars              1995  AFC South
# 30     Arizona Cardinals              1920   NFC West
# 31  Tampa Bay Buccaneers              1976  NFC South

# %%
# save our data to a pickle file
nfl_data.to_pickle("./nfl_data.pkl")

# %%
# read it to a new dataframe
nfl_frame = pd.read_pickle("./nfl_data.pkl")
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# 14    15      Seattle Seahawks    692  355   336     1  0.514
# 15    16      Los Angeles Rams  1,167  577   569    21  0.503
# 16    17   Washington Redskins  1,234  603   603    28  0.500
# 17    18  Los Angeles Chargers    916  452   453    11  0.499
# 18    19   Philadelphia Eagles   1,22  586   608    26  0.491
# 19    20     Carolina Panthers    400  195   204     1  0.489
# 20    21      Cleveland Browns    986  475   500    11  0.487
# 21    22      Tennessee Titans    916  440   470     6  0.484
# 22    23         Buffalo Bills    916  425   483     8  0.468
# 23    24    New Orleans Saints    818  375   438     5  0.461
# 24    25         Detroit Lions  1,265  562   670    33  0.457
# 25    26        Houston Texans    288  131   157     0  0.455
# 26    27         New York Jets    916  408   500     8  0.450
# 27    28    Cincinnati Bengals    804  359   441     4  0.449
# 28    29       Atlanta Falcons    832  365   461     6  0.448
# 29    30  Jacksonville Jaguars    400  176   224     0  0.440
# 30    31     Arizona Cardinals  1,362  558   763    41  0.425
# 31    32  Tampa Bay Buccaneers    692  267   424     1  0.387
#
#     First NFL Season   Division
# 0               1960   NFC East
# 1               1921  NFC North
# 2               1960   AFC East
# 3               1920  NFC North
# 4               1996  AFC North
# 5               1966   AFC East
# 6               1961  NFC North
# 7               1950   NFC West
# 8               1925   NFC East
# 9               1960   AFC West
# 10              1960   AFC West
# 11              1933  AFC North
# 12              1953  AFC South
# 13              1960   AFC West
# 14              1976   NFC West
# 15              1937   NFC West
# 16              1932   NFC East
# 17              1960   AFC West
# 18              1933   NFC East
# 19              1995  NFC South
# 20              1950  AFC North
# 21              1960  AFC South
# 22              1960   AFC East
# 23              1967  NFC South
# 24              1930  NFC North
# 25              2002  AFC South
# 26              1960   AFC East
# 27              1968  AFC North
# 28              1966  NFC South
# 29              1995  AFC South
# 30              1920   NFC West
# 31              1976  NFC South

# %%
# call a column that does not exist in the dataframe
# Stadium is not in the dataframe, pandas will create a column with this name 

DataFrame(nfl_frame, columns = ['Team', 'GP', 'Won', 'Lost', 'Stadium']).head()
# Out:
#                    Team     GP  Won  Lost  Stadium
# 0        Dallas Cowboys    914  520   388      NaN
# 1     Green Bay Packers  1,368  756   574      NaN
# 2  New England Patriots    916  512   395      NaN
# 3         Chicago Bears  1,402  769   591      NaN
# 4      Baltimore Ravens    384  214   169      NaN

# %%
# call columns by its name
nfl_frame.Team.head()
# Out:
# 0          Dallas Cowboys
# 1       Green Bay Packers
# 2    New England Patriots
# 3           Chicago Bears
# 4        Baltimore Ravens
# Name: Team, dtype: object

# %%
# call rows by its index -> loc or iloc
nfl_frame.iloc[3]
# Out:
# Rank                            4
# Team                Chicago Bears
# GP                          1,402
# Won                           769
# Lost                          591
# Tied                           42
# Pct.                        0.563
# First NFL Season             1920
# Division                NFC North
# Name: 3, dtype: object

# %%
# add new column, add numbers as values
nfl_frame['Stadium'] = np.arange(len(nfl_frame['Team']))
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# 14    15      Seattle Seahawks    692  355   336     1  0.514
# 15    16      Los Angeles Rams  1,167  577   569    21  0.503
# 16    17   Washington Redskins  1,234  603   603    28  0.500
# 17    18  Los Angeles Chargers    916  452   453    11  0.499
# 18    19   Philadelphia Eagles   1,22  586   608    26  0.491
# 19    20     Carolina Panthers    400  195   204     1  0.489
# 20    21      Cleveland Browns    986  475   500    11  0.487
# 21    22      Tennessee Titans    916  440   470     6  0.484
# 22    23         Buffalo Bills    916  425   483     8  0.468
# 23    24    New Orleans Saints    818  375   438     5  0.461
# 24    25         Detroit Lions  1,265  562   670    33  0.457
# 25    26        Houston Texans    288  131   157     0  0.455
# 26    27         New York Jets    916  408   500     8  0.450
# 27    28    Cincinnati Bengals    804  359   441     4  0.449
# 28    29       Atlanta Falcons    832  365   461     6  0.448
# 29    30  Jacksonville Jaguars    400  176   224     0  0.440
# 30    31     Arizona Cardinals  1,362  558   763    41  0.425
# 31    32  Tampa Bay Buccaneers    692  267   424     1  0.387
#
#     First NFL Season   Division  Stadium
# 0               1960   NFC East        0
# 1               1921  NFC North        1
# 2               1960   AFC East        2
# 3               1920  NFC North        3
# 4               1996  AFC North        4
# 5               1966   AFC East        5
# 6               1961  NFC North        6
# 7               1950   NFC West        7
# 8               1925   NFC East        8
# 9               1960   AFC West        9
# 10              1960   AFC West       10
# 11              1933  AFC North       11
# 12              1953  AFC South       12
# 13              1960   AFC West       13
# 14              1976   NFC West       14
# 15              1937   NFC West       15
# 16              1932   NFC East       16
# 17              1960   AFC West       17
# 18              1933   NFC East       18
# 19              1995  NFC South       19
# 20              1950  AFC North       20
# 21              1960  AFC South       21
# 22              1960   AFC East       22
# 23              1967  NFC South       23
# 24              1930  NFC North       24
# 25              2002  AFC South       25
# 26              1960   AFC East       26
# 27              1968  AFC North       27
# 28              1966  NFC South       28
# 29              1995  AFC South       29
# 30              1920   NFC West       30
# 31              1976  NFC South       31

# %%
# delete columns !!
del nfl_frame['Stadium']
nfl_frame.head()
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    914  520   388     6  0.572
# 1     2     Green Bay Packers  1,368  756   574    38  0.567
# 2     3  New England Patriots    916  512   395     9  0.564
# 3     4         Chicago Bears  1,402  769   591    42  0.563
# 4     5      Baltimore Ravens    384  214   169     1  0.559
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
# convert equal lenght list in a dictionary to a DataFrame
age_data = {'People':['Peter', 'Bob', 'Marduk'], 'Age':[34, 43, 43]}
age_df = DataFrame(age_data)
age_df.head()
# Out:
#    People  Age
# 0   Peter   34
# 1     Bob   43
# 2  Marduk   43
